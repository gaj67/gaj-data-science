# %% [markdown]
# # References

# %% [markdown]
# <a id="K2011">[K2011]</a> J. Kerman (2011): "*Neutral noninformative and informative conjugate beta and gamma prior distributions*", Electron. J. Statist. 5: 1450-1470.
#
# <a id="CB2002">[CB2002]</a> G. Casella and R. L. Berger (2002): "*Statistical Inference*," second edition.
#
# <a id="D2015">[D2015]</a> A. Drory (2015): "*Failure and uses of Jaynes’ principle of transformation groups*."
# ([ref](https://www.researchgate.net/publication/273477459_Failure_and_Uses_of_Jaynes%27_Principle_of_Transformation_Groups "www.researchgate.net"))
#
# <a id="Z1996">[Z1996]</a> A. Zellner (1996): "*An introduction to Bayesian inference in econometrics*," Wiley.
# ([ref](https://www.wiley.com/en-au/An+Introduction+to+Bayesian+Inference+in+Econometrics-p-9780471169376
# "www.wiley.com"))
#
# <a id="GCSR1995">[GCSR1995]</a> A. Gelman, J. B. Carlin, H. S. Stern and D. B. Rubin (1995): "*Bayesian Data Analysis*," Chapman and Hall.
#
# <a id="M1983">[M1983]</a> P. Milne (1983): "*A note on scale invariance*".
# ([ref](https://www.jstor.org/stable/686933 "www.jstor.org"))
#
# <a id="BT1973">[BT1973]</a> G. E. P. Box and G. C. Tiao (1973): "*Bayesian Inference in Statistical Analysis*", John Wiley & Sons.
#
# <a id="J1973">[J1973]</a> E.T. Jaynes (1973): "*The well-posed problem*".
# ([pdf](https://bayes.wustl.edu/etj/articles/well.pdf "bayes.wustl.edu"))
#
# <a id="J1964">[J1964]</a> E.T. Jaynes (1964): "*Prior probabilities and transformation groups*".
# ([pdf](https://bayes.wustl.edu/etj/articles/groups.pdf "bayes.wustl.edu"))
